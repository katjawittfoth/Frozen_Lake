# %%
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
from frozen_lake_env import FrozenLakeEnv
from q_game import QFrozenLakeAgent, play
from IPython.display import clear_output

# %%
agent = QFrozenLakeAgent()

# %%
agent.train()
# Out:
# Episode: 0, Average reward: 0.0
# Episode: 1,000, Average reward: 0.03
# Episode: 2,000, Average reward: 0.01
# Episode: 3,000, Average reward: 0.0
# Episode: 4,000, Average reward: 0.0
# Episode: 5,000, Average reward: 0.01
# Episode: 6,000, Average reward: 0.0
# Episode: 7,000, Average reward: 0.02
# Episode: 8,000, Average reward: 0.06
# Episode: 9,000, Average reward: 0.08
# Episode: 10,000, Average reward: 0.11
# Episode: 11,000, Average reward: 0.27
# Episode: 12,000, Average reward: 0.28
# Episode: 13,000, Average reward: 0.32
# Episode: 14,000, Average reward: 0.25
# Episode: 15,000, Average reward: 0.34
# Episode: 16,000, Average reward: 0.31
# Episode: 17,000, Average reward: 0.41
# Episode: 18,000, Average reward: 0.48
# Episode: 19,000, Average reward: 0.46
# Episode: 20,000, Average reward: 0.64
# Episode: 21,000, Average reward: 0.59
# Episode: 22,000, Average reward: 0.65
# Episode: 23,000, Average reward: 0.59
# Episode: 24,000, Average reward: 0.68
# Episode: 25,000, Average reward: 0.77
# Episode: 26,000, Average reward: 0.74
# Episode: 27,000, Average reward: 0.68
# Episode: 28,000, Average reward: 0.74
# Episode: 29,000, Average reward: 0.66
# Episode: 30,000, Average reward: 0.71
# Episode: 31,000, Average reward: 0.66
# Episode: 32,000, Average reward: 0.7
# Episode: 33,000, Average reward: 0.76
# Episode: 34,000, Average reward: 0.7
# Episode: 35,000, Average reward: 0.48
# Episode: 36,000, Average reward: 0.69
# Episode: 37,000, Average reward: 0.73
# Episode: 38,000, Average reward: 0.8
# Episode: 39,000, Average reward: 0.79
# Episode: 40,000, Average reward: 0.47
# Episode: 41,000, Average reward: 0.76
# Episode: 42,000, Average reward: 0.82
# Frozen Lake solved 🏆🏆🏆

# %%
agent.plot()

# %%
play(agent, num_episodes=5)
# Out:
#   (Down)
# 🏁❄️❄️❄️
# ❄️🕳❄️🕳
# ❄️❄️❄️🕳
# 🕳❄️❄️🏆
# Yay! 🏆 You have found your 🥏 in 23 steps.
